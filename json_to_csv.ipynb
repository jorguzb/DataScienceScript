# %% [markdown]
# <a href="https://colab.research.google.com/github/jorguzb/DataScienceScript/blob/master/json_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas

def cross_join(left, right):
    return left.assign(key=1).merge(right.assign(key=1), on='key', how='outer').drop('key', 1)

def json_to_dataframe(data_in):
    def to_frame(data, prev_key=""):
        if isinstance(data, dict):
            df = pandas.DataFrame()
            for key in data:
                #print(to_frame(data[key], prev_key + '.' + key))
                df = cross_join(df, to_frame(data[key], prev_key + '.' + key))
        elif isinstance(data, list):
            df = pandas.DataFrame()
            for i in range(len(data)):
                df = pandas.concat([df, to_frame(data[i], prev_key)])
        else:
            df = pandas.DataFrame({prev_key[1:]: [data]})
        return df
    return to_frame(data_in)

if __name__ == '__main__':
    with open('datamodel-c759d9a6-baa3-4ec9-9df7-27f26ed7fd6e.json') as json_file:
        json_data = json.load(json_file)

    df = json_to_dataframe(json_data)
    df.to_csv('data.csv', mode='w')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-294da798e21e> in <module>
#      25         json_data = json.load(json_file)
#      26
# ---> 27     df = json_to_dataframe(json_data)
#      28     df.to_csv('data.csv', mode='w')
#
# <ipython-input-2-294da798e21e> in json_to_dataframe(data_in)
#      19             df = pandas.DataFrame({prev_key[1:]: [data]})
#      20         return df
# ---> 21     return to_frame(data_in)
#      22
#      23 if __name__ == '__main__':
#
# <ipython-input-2-294da798e21e> in to_frame(data, prev_key)
#      11             for key in data:
#      12                 #print(to_frame(data[key], prev_key + '.' + key))
# ---> 13                 df = cross_join(df, to_frame(data[key], prev_key + '.' + key))
#      14         elif isinstance(data, list):
#      15             df = pandas.DataFrame()
#
# ...
